# %% [markdown]
# # ISMN Data Processing Script
# This script takes processes ISMN header-value data, generates CSV text file and dictionaries of station names and coordinates

# %%
from ismn.interface import ISMN_Interface
from datetime import datetime
import matplotlib.pyplot as plt
import random
import pandas
import json
# %matplotlib inline

# %%
path_to_ismn_data = '..'

# %%
#initialize interface, this can take up to a few minutes the first
#time, since all metadata has to be collected

ISMN_reader = ISMN_Interface(path_to_ismn_data)

#plot available station on a map
fig, ax = ISMN_reader.plot_station_locations()
plt.show()

# %%
networks = ISMN_reader.list_networks()
print("Available Networks:")
print(networks)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f669bb92e746> in <module>
# ----> 1 networks = ISMN_reader.list_networks()
#       2 print("Available Networks:")
#       3 print(networks)
#
# NameError: name 'ISMN_reader' is not defined

# %%
# print list of stations for each network
for network in networks: 
    stations = ISMN_reader.list_stations(network)
    print("Available Stations in Network %s"%network)
    print(stations)

# %% [markdown]
# # Generating CSV

# %%
current_time = datetime.now() 
# timestamp format
timestamp = current_time.strftime("%Y%m%d%H%M%S")
use_timestamp_in_filename = False

# string to append to filename, add timestamp if needed
if (use_timestamp_in_filename):
    filename_string = '_latlon_' + timestamp + '.csv'
else:
    filename_string = '_latlon.csv'

# create dataframe for each network and export to each network dataframe to csv
for network in networks: 
    stations = ISMN_reader.list_stations(network)
    network_df = pandas.DataFrame()
    network_df = pandas.DataFrame(columns = ['name', 'latitude', 'longitude'])
    for station in stations:
        station_obj = ISMN_reader.get_station(station)
        network_df = network_df.append({'name' : station_obj.station, 'latitude' : station_obj.latitude, 'longitude' : station_obj.longitude} , ignore_index=True)
    network_df.to_csv (network + filename_string, index = False, header=True, sep = " ")

# %% [markdown]
# # Generating dictionary of all stations

# %%
stations = {}

for network in networks:
    stations = ISMN_reader.list_stations(network)    
    for station in stations:
        station_obj = ISMN_reader.get_station(station)
        stations[network][station][lon] = station_obj.longitude
        stations[network][station][lat] = station_obj.latitude
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6fe2dc66d105> in <module>
#       1 stations = {}
#       2
# ----> 3 for network in networks:
#       4     stations = ISMN_reader.list_stations(network)
#       5     for station in stations:
#
# NameError: name 'networks' is not defined

# %% [markdown]
# # Generating dictionaries and exporting to text

# %%
for network in networks: 
    stations = ISMN_reader.list_stations(network)    
    dict = {}
    for station in stations:
        station_obj = ISMN_reader.get_station(station)
        dict[station_obj.station] = (station_obj.latitude, station_obj.longitude)
    ffilename = network + "_latlon_dict.txt"
    f = open(ffilename,"w")
    f.write(str(dict))
    f.close()

# %% [markdown]
# # Generating dictionaries and exporting to json

# %%
for network in networks: 
    stations = ISMN_reader.list_stations(network)    
    dict = {}
    for station in stations:
        station_obj = ISMN_reader.get_station(station)
        dict[station_obj.station] = (station_obj.latitude, station_obj.longitude)
#     print(type(dict))
    json_dump = json.dumps(dict)
#     print(json_dump)
    jfilename = network + "_latlon_dict.json"
    j = open(jfilename,"w")
    j.write(json_dump)
    j.close()

# %% [markdown]
# # Printing Dictionary Values

# %%
for network in networks: 
    stations = ISMN_reader.list_stations(network)    
    dict = {}
    for station in stations:
        station_obj = ISMN_reader.get_station(station)
        dict[station_obj.station] = (station_obj.latitude, station_obj.longitude)
        # test printing
        for keys,values in dict.items():
            print(network + " " + keys + " " + repr(values[0]) + " " + repr(values[1]))
# Out:
# FMI SAA111 68.33019 27.55062
# FMI SAA111 68.33019 27.55062
# FMI SAA112 68.33025 27.55076
# FMI SAA111 68.33019 27.55062
# FMI SAA112 68.33025 27.55076
# FMI SAA120 68.33881 27.53543
# FMI SAA111 68.33019 27.55062
# FMI SAA112 68.33025 27.55076
# FMI SAA120 68.33881 27.53543
# FMI SOD011 67.36187 26.63378
# FMI SAA111 68.33019 27.55062
# FMI SAA112 68.33025 27.55076
# FMI SAA120 68.33881 27.53543
# FMI SOD011 67.36187 26.63378
# FMI SOD012 67.36179 26.63378
# FMI SAA111 68.33019 27.55062
# FMI SAA112 68.33025 27.55076
# FMI SAA120 68.33881 27.53543
# FMI SOD011 67.36187 26.63378
# FMI SOD012 67.36179 26.63378
# FMI SOD013 67.36195 26.63378
# FMI SAA111 68.33019 27.55062
# FMI SAA112 68.33025 27.55076
# FMI SAA120 68.33881 27.53543
# FMI SOD011 67.36187 26.63378
# FMI SOD012 67.36179 26.63378
# FMI SOD013 67.36195 26.63378
# FMI SOD021 67.36691 26.65176
# FMI SAA111 68.33019 27.55062
# FMI SAA112 68.33025 27.55076
# FMI SAA120 68.33881 27.53543
# FMI SOD011 67.36187 26.63378
# FMI SOD012 67.36179 26.63378
# FMI SOD013 67.36195 26.63378
# FMI SOD021 67.36691 26.65176
# FMI SOD022 67.36685 26.65162
# FMI SAA111 68.33019 27.55062
# FMI SAA112 68.33025 27.55076
# FMI SAA120 68.33881 27.53543
# FMI SOD011 67.36187 26.63378
# FMI SOD012 67.36179 26.63378
# FMI SOD013 67.36195 26.63378
# FMI SOD021 67.36691 26.65176
# FMI SOD022 67.36685 26.65162
# FMI SOD023 67.36691 26.65196
# FMI SAA111 68.33019 27.55062
# FMI SAA112 68.33025 27.55076
# FMI SAA120 68.33881 27.53543
# FMI SOD011 67.36187 26.63378
# FMI SOD012 67.36179 26.63378
# FMI SOD013 67.36195 26.63378
# FMI SOD021 67.36691 26.65176
# FMI SOD022 67.36685 26.65162
# FMI SOD023 67.36691 26.65196
# FMI SOD031 67.36702 26.65064
# FMI SAA111 68.33019 27.55062
# FMI SAA112 68.33025 27.55076
# FMI SAA120 68.33881 27.53543
# FMI SOD011 67.36187 26.63378
# FMI SOD012 67.36179 26.63378
# FMI SOD013 67.36195 26.63378
# FMI SOD021 67.36691 26.65176
# FMI SOD022 67.36685 26.65162
# FMI SOD023 67.36691 26.65196
# FMI SOD031 67.36702 26.65064
# FMI SOD032 67.367 26.65056
# FMI SAA111 68.33019 27.55062
# FMI SAA112 68.33025 27.55076
# FMI SAA120 68.33881 27.53543
# FMI SOD011 67.36187 26.63378
# FMI SOD012 67.36179 26.63378
# FMI SOD013 67.36195 26.63378
# FMI SOD021 67.36691 26.65176
# FMI SOD022 67.36685 26.65162
# FMI SOD023 67.36691 26.65196
# FMI SOD031 67.36702 26.65064
# FMI SOD032 67.367 26.65056
# FMI SOD033 67.36696 26.65073
# FMI SAA111 68.33019 27.55062
# FMI SAA112 68.33025 27.55076
# FMI SAA120 68.33881 27.53543
# FMI SOD011 67.36187 26.63378
# FMI SOD012 67.36179 26.63378
# FMI SOD013 67.36195 26.63378
# FMI SOD021 67.36691 26.65176
# FMI SOD022 67.36685 26.65162
# FMI SOD023 67.36691 26.65196
# FMI SOD031 67.36702 26.65064
# FMI SOD032 67.367 26.65056
# FMI SOD033 67.36696 26.65073
# FMI SOD071 67.35687 26.68492
# FMI SAA111 68.33019 27.55062
# FMI SAA112 68.33025 27.55076
# FMI SAA120 68.33881 27.53543
# FMI SOD011 67.36187 26.63378
# FMI SOD012 67.36179 26.63378
# FMI SOD013 67.36195 26.63378
# FMI SOD021 67.36691 26.65176
# FMI SOD022 67.36685 26.65162
# FMI SOD023 67.36691 26.65196
# FMI SOD031 67.36702 26.65064
# FMI SOD032 67.367 26.65056
# FMI SOD033 67.36696 26.65073
# FMI SOD071 67.35687 26.68492
# FMI SOD072 67.35693 26.68506
# FMI SAA111 68.33019 27.55062
# FMI SAA112 68.33025 27.55076
# FMI SAA120 68.33881 27.53543
# FMI SOD011 67.36187 26.63378
# FMI SOD012 67.36179 26.63378
# FMI SOD013 67.36195 26.63378
# FMI SOD021 67.36691 26.65176
# FMI SOD022 67.36685 26.65162
# FMI SOD023 67.36691 26.65196
# FMI SOD031 67.36702 26.65064
# FMI SOD032 67.367 26.65056
# FMI SOD033 67.36696 26.65073
# FMI SOD071 67.35687 26.68492
# FMI SOD072 67.35693 26.68506
# FMI SOD073 67.35681 26.68478
# FMI SAA111 68.33019 27.55062
# FMI SAA112 68.33025 27.55076
# FMI SAA120 68.33881 27.53543
# FMI SOD011 67.36187 26.63378
# FMI SOD012 67.36179 26.63378
# FMI SOD013 67.36195 26.63378
# FMI SOD021 67.36691 26.65176
# FMI SOD022 67.36685 26.65162
# FMI SOD023 67.36691 26.65196
# FMI SOD031 67.36702 26.65064
# FMI SOD032 67.367 26.65056
# FMI SOD033 67.36696 26.65073
# FMI SOD071 67.35687 26.68492
# FMI SOD072 67.35693 26.68506
# FMI SOD073 67.35681 26.68478
# FMI SOD081 67.38425 26.62529
# FMI SAA111 68.33019 27.55062
# FMI SAA112 68.33025 27.55076
# FMI SAA120 68.33881 27.53543
# FMI SOD011 67.36187 26.63378
# FMI SOD012 67.36179 26.63378
# FMI SOD013 67.36195 26.63378
# FMI SOD021 67.36691 26.65176
# FMI SOD022 67.36685 26.65162
# FMI SOD023 67.36691 26.65196
# FMI SOD031 67.36702 26.65064
# FMI SOD032 67.367 26.65056
# FMI SOD033 67.36696 26.65073
# FMI SOD071 67.35687 26.68492
# FMI SOD072 67.35693 26.68506
# FMI SOD073 67.35681 26.68478
# FMI SOD081 67.38425 26.62529
# FMI SOD082 67.38419 26.62515
# FMI SAA111 68.33019 27.55062
# FMI SAA112 68.33025 27.55076
# FMI SAA120 68.33881 27.53543
# FMI SOD011 67.36187 26.63378
# FMI SOD012 67.36179 26.63378
# FMI SOD013 67.36195 26.63378
# FMI SOD021 67.36691 26.65176
# FMI SOD022 67.36685 26.65162
# FMI SOD023 67.36691 26.65196
# FMI SOD031 67.36702 26.65064
# FMI SOD032 67.367 26.65056
# FMI SOD033 67.36696 26.65073
# FMI SOD071 67.35687 26.68492
# FMI SOD072 67.35693 26.68506
# FMI SOD073 67.35681 26.68478
# FMI SOD081 67.38425 26.62529
# FMI SOD082 67.38419 26.62515
# FMI SOD083 67.38431 26.62515
# FMI SAA111 68.33019 27.55062
# FMI SAA112 68.33025 27.55076
# FMI SAA120 68.33881 27.53543
# FMI SOD011 67.36187 26.63378
# FMI SOD012 67.36179 26.63378
# FMI SOD013 67.36195 26.63378
# FMI SOD021 67.36691 26.65176
# FMI SOD022 67.36685 26.65162
# FMI SOD023 67.36691 26.65196
# FMI SOD031 67.36702 26.65064
# FMI SOD032 67.367 26.65056
# FMI SOD033 67.36696 26.65073
# FMI SOD071 67.35687 26.68492
# FMI SOD072 67.35693 26.68506
# FMI SOD073 67.35681 26.68478
# FMI SOD081 67.38425 26.62529
# FMI SOD082 67.38419 26.62515
# FMI SOD083 67.38431 26.62515
# FMI SOD091 67.37079 26.6398
# FMI SAA111 68.33019 27.55062
# FMI SAA112 68.33025 27.55076
# FMI SAA120 68.33881 27.53543
# FMI SOD011 67.36187 26.63378
# FMI SOD012 67.36179 26.63378
# FMI SOD013 67.36195 26.63378
# FMI SOD021 67.36691 26.65176
# FMI SOD022 67.36685 26.65162
# FMI SOD023 67.36691 26.65196
# FMI SOD031 67.36702 26.65064
# FMI SOD032 67.367 26.65056
# FMI SOD033 67.36696 26.65073
# FMI SOD071 67.35687 26.68492
# FMI SOD072 67.35693 26.68506
# FMI SOD073 67.35681 26.68478
# FMI SOD081 67.38425 26.62529
# FMI SOD082 67.38419 26.62515
# FMI SOD083 67.38431 26.62515
# FMI SOD091 67.37079 26.6398
# FMI SOD092 67.37074 26.63978
# FMI SAA111 68.33019 27.55062
# FMI SAA112 68.33025 27.55076
# FMI SAA120 68.33881 27.53543
# FMI SOD011 67.36187 26.63378
# FMI SOD012 67.36179 26.63378
# FMI SOD013 67.36195 26.63378
# FMI SOD021 67.36691 26.65176
# FMI SOD022 67.36685 26.65162
# FMI SOD023 67.36691 26.65196
# FMI SOD031 67.36702 26.65064
# FMI SOD032 67.367 26.65056
# FMI SOD033 67.36696 26.65073
# FMI SOD071 67.35687 26.68492
# FMI SOD072 67.35693 26.68506
# FMI SOD073 67.35681 26.68478
# FMI SOD081 67.38425 26.62529
# FMI SOD082 67.38419 26.62515
# FMI SOD083 67.38431 26.62515
# FMI SOD091 67.37079 26.6398
# FMI SOD092 67.37074 26.63978
# FMI SOD093 67.37083 26.63971
# FMI SAA111 68.33019 27.55062
# FMI SAA112 68.33025 27.55076
# FMI SAA120 68.33881 27.53543
# FMI SOD011 67.36187 26.63378
# FMI SOD012 67.36179 26.63378
# FMI SOD013 67.36195 26.63378
# FMI SOD021 67.36691 26.65176
# FMI SOD022 67.36685 26.65162
# FMI SOD023 67.36691 26.65196
# FMI SOD031 67.36702 26.65064
# FMI SOD032 67.367 26.65056
# FMI SOD033 67.36696 26.65073
# FMI SOD071 67.35687 26.68492
# FMI SOD072 67.35693 26.68506
# FMI SOD073 67.35681 26.68478
# FMI SOD081 67.38425 26.62529
# FMI SOD082 67.38419 26.62515
# FMI SOD083 67.38431 26.62515
# FMI SOD091 67.37079 26.6398
# FMI SOD092 67.37074 26.63978
# FMI SOD093 67.37083 26.63971
# FMI SOD101 67.35919 26.68595
# FMI SAA111 68.33019 27.55062
# FMI SAA112 68.33025 27.55076
# FMI SAA120 68.33881 27.53543
# FMI SOD011 67.36187 26.63378
# FMI SOD012 67.36179 26.63378
# FMI SOD013 67.36195 26.63378
# FMI SOD021 67.36691 26.65176
# FMI SOD022 67.36685 26.65162
# FMI SOD023 67.36691 26.65196
# FMI SOD031 67.36702 26.65064
# FMI SOD032 67.367 26.65056
# FMI SOD033 67.36696 26.65073
# FMI SOD071 67.35687 26.68492
# FMI SOD072 67.35693 26.68506
# FMI SOD073 67.35681 26.68478
# FMI SOD081 67.38425 26.62529
# FMI SOD082 67.38419 26.62515
# FMI SOD083 67.38431 26.62515
# FMI SOD091 67.37079 26.6398
# FMI SOD092 67.37074 26.63978
# FMI SOD093 67.37083 26.63971
# FMI SOD101 67.35919 26.68595
# FMI SOD102 67.35922 26.68595
# FMI SAA111 68.33019 27.55062
# FMI SAA112 68.33025 27.55076
# FMI SAA120 68.33881 27.53543
# FMI SOD011 67.36187 26.63378
# FMI SOD012 67.36179 26.63378
# FMI SOD013 67.36195 26.63378
# FMI SOD021 67.36691 26.65176
# FMI SOD022 67.36685 26.65162
# FMI SOD023 67.36691 26.65196
# FMI SOD031 67.36702 26.65064
# FMI SOD032 67.367 26.65056
# FMI SOD033 67.36696 26.65073
# FMI SOD071 67.35687 26.68492
# FMI SOD072 67.35693 26.68506
# FMI SOD073 67.35681 26.68478
# FMI SOD081 67.38425 26.62529
# FMI SOD082 67.38419 26.62515
# FMI SOD083 67.38431 26.62515
# FMI SOD091 67.37079 26.6398
# FMI SOD092 67.37074 26.63978
# FMI SOD093 67.37083 26.63971
# FMI SOD101 67.35919 26.68595
# FMI SOD102 67.35922 26.68595
# FMI SOD103 67.35917 26.68594
# FMI SAA111 68.33019 27.55062
# FMI SAA112 68.33025 27.55076
# FMI SAA120 68.33881 27.53543
# FMI SOD011 67.36187 26.63378
# FMI SOD012 67.36179 26.63378
# FMI SOD013 67.36195 26.63378
# FMI SOD021 67.36691 26.65176
# FMI SOD022 67.36685 26.65162
# FMI SOD023 67.36691 26.65196
# FMI SOD031 67.36702 26.65064
# FMI SOD032 67.367 26.65056
# FMI SOD033 67.36696 26.65073
# FMI SOD071 67.35687 26.68492
# FMI SOD072 67.35693 26.68506
# FMI SOD073 67.35681 26.68478
# FMI SOD081 67.38425 26.62529
# FMI SOD082 67.38419 26.62515
# FMI SOD083 67.38431 26.62515
# FMI SOD091 67.37079 26.6398
# FMI SOD092 67.37074 26.63978
# FMI SOD093 67.37083 26.63971
# FMI SOD101 67.35919 26.68595
# FMI SOD102 67.35922 26.68595
# FMI SOD103 67.35917 26.68594
# FMI SOD130 67.25729 26.74857
# FMI SAA111 68.33019 27.55062
# FMI SAA112 68.33025 27.55076
# FMI SAA120 68.33881 27.53543
# FMI SOD011 67.36187 26.63378
# FMI SOD012 67.36179 26.63378
# FMI SOD013 67.36195 26.63378
# FMI SOD021 67.36691 26.65176
# FMI SOD022 67.36685 26.65162
# FMI SOD023 67.36691 26.65196
# FMI SOD031 67.36702 26.65064
# FMI SOD032 67.367 26.65056
# FMI SOD033 67.36696 26.65073
# FMI SOD071 67.35687 26.68492
# FMI SOD072 67.35693 26.68506
# FMI
# HOBE 1.01 56.0193 9.1809
# HOBE 1.02 56.0376 9.161
# HOBE 1.03 56.0283 9.1654
# HOBE 1.04 56.0733 9.3337
# HOBE 1.05 56.033 9.1912
# HOBE 1.06 56.0513 9.161
# HOBE 1.07 56.0426 9.1413
# HOBE 1.08 56.0466 9.1239
# HOBE 1.09 56.036 9.1304
# HOBE 1.10 56.0348 9.2392
# HOBE 2.01 55.9398 9.2207
# HOBE 2.02 55.9839 9.1624
# HOBE 2.03 55.9816 9.1526
# HOBE 2.04 55.9759 9.0984
# HOBE 2.05 55.9763 9.0967
# HOBE 2.06b 55.9797 9.0817
# HOBE 2.07 55.9482 9.0337
# HOBE 2.08b 55.9397 9.03146
# HOBE 2.09 55.9282 9.1153
# HOBE 2.10 55.9861 9.0907
# HOBE 2.11 55.9704 9.0225
# HOBE 3.01 55.8807 9.0142
# HOBE 3.02 55.9354 8.9221
# HOBE 3.03 55.9121 8.9462
# HOBE 3.04 55.9106 8.9357
# HOBE 3.05 55.9025 8.9175
# HOBE 1.01 56.0193 9.1809
# HOBE 1.02 56.0376 9.161
# HOBE 1.03 56.0283 9.1654
# HOBE 1.04 56.0733 9.3337
# HOBE 1.05 56.033 9.1912
# HOBE 1.06 56.0513 9.161
# HOBE 1.07 56.0426 9.1413
# HOBE 1.08 56.0466 9.1239
# HOBE 1.09 56.036 9.1304
# HOBE 1.10 56.0348 9.2392
# HOBE 2.01 55.9398 9.2207
# HOBE 2.02 55.9839 9.1624
# HOBE 2.03 55.9816 9.1526
# HOBE 2.04 55.9759 9.0984
# HOBE 2.05 55.9763 9.0967
# HOBE 2.06b 55.9797 9.0817
# HOBE 2.07 55.9482 9.0337
# HOBE 2.08b 55.9397 9.03146
# HOBE 2.09 55.9282 9.1153
# HOBE 2.10 55.9861 9.0907
# HOBE 2.11 55.9704 9.0225
# HOBE 3.01 55.8807 9.0142
# HOBE 3.02 55.9354 8.9221
# HOBE 3.03 55.9121 8.9462
# HOBE 3.04 55.9106 8.9357
# HOBE 3.05 55.9025 8.9175
# HOBE 3.06 55.9115 8.8831
# HOBE 1.01 56.0193 9.1809
# HOBE 1.02 56.0376 9.161
# HOBE 1.03 56.0283 9.1654
# HOBE 1.04 56.0733 9.3337
# HOBE 1.05 56.033 9.1912
# HOBE 1.06 56.0513 9.161
# HOBE 1.07 56.0426 9.1413
# HOBE 1.08 56.0466 9.1239
# HOBE 1.09 56.036 9.1304
# HOBE 1.10 56.0348 9.2392
# HOBE 2.01 55.9398 9.2207
# HOBE 2.02 55.9839 9.1624
# HOBE 2.03 55.9816 9.1526
# HOBE 2.04 55.9759 9.0984
# HOBE 2.05 55.9763 9.0967
# HOBE 2.06b 55.9797 9.0817
# HOBE 2.07 55.9482 9.0337
# HOBE 2.08b 55.9397 9.03146
# HOBE 2.09 55.9282 9.1153
# HOBE 2.10 55.9861 9.0907
# HOBE 2.11 55.9704 9.0225
# HOBE 3.01 55.8807 9.0142
# HOBE 3.02 55.9354 8.9221
# HOBE 3.03 55.9121 8.9462
# HOBE 3.04 55.9106 8.9357
# HOBE 3.05 55.9025 8.9175
# HOBE 3.06 55.9115 8.8831
# HOBE 3.07 55.9096 8.8536
# HOBE 1.01 56.0193 9.1809
# HOBE 1.02 56.0376 9.161
# HOBE 1.03 56.0283 9.1654
# HOBE 1.04 56.0733 9.3337
# HOBE 1.05 56.033 9.1912
# HOBE 1.06 56.0513 9.161
# HOBE 1.07 56.0426 9.1413
# HOBE 1.08 56.0466 9.1239
# HOBE 1.09 56.036 9.1304
# HOBE 1.10 56.0348 9.2392
# HOBE 2.01 55.9398 9.2207
# HOBE 2.02 55.9839 9.1624
# HOBE 2.03 55.9816 9.1526
# HOBE 2.04 55.9759 9.0984
# HOBE 2.05 55.9763 9.0967
# HOBE 2.06b 55.9797 9.0817
# HOBE 2.07 55.9482 9.0337
# HOBE 2.08b 55.9397 9.03146
# HOBE 2.09 55.9282 9.1153
# HOBE 2.10 55.9861 9.0907
# HOBE 2.11 55.9704 9.0225
# HOBE 3.01 55.8807 9.0142
# HOBE 3.02 55.9354 8.9221
# HOBE 3.03 55.9121 8.9462
# HOBE 3.04 55.9106 8.9357
# HOBE 3.05 55.9025 8.9175
# HOBE 3.06 55.9115 8.8831
# HOBE 3.07 55.9096 8.8536
# HOBE 3.08 55.8776 9.2683
# HOBE 1.01 56.0193 9.1809
# HOBE 1.02 56.0376 9.161
# HOBE 1.03 56.0283 9.1654
# HOBE 1.04 56.0733 9.3337
# HOBE 1.05 56.033 9.1912
# HOBE 1.06 56.0513 9.161
# HOBE 1.07 56.0426 9.1413
# HOBE 1.08 56.0466 9.1239
# HOBE 1.09 56.036 9.1304
# HOBE 1.10 56.0348 9.2392
# HOBE 2.01 55.9398 9.2207
# HOBE 2.02 55.9839 9.1624
# HOBE 2.03 55.9816 9.1526
# HOBE 2.04 55.9759 9.0984
# HOBE 2.05 55.9763 9.0967
# HOBE 2.06b 55.9797 9.0817
# HOBE 2.07 55.9482 9.0337
# HOBE 2.08b 55.9397 9.03146
# HOBE 2.09 55.9282 9.1153
# HOBE 2.10 55.9861 9.0907
# HOBE 2.11 55.9704 9.0225
# HOBE 3.01 55.8807 9.0142
# HOBE 3.02 55.9354 8.9221
# HOBE 3.03 55.9121 8.9462
# HOBE 3.04 55.9106 8.9357
# HOBE 3.05 55.9025 8.9175
# HOBE 3.06 55.9115 8.8831
# HOBE 3.07 55.9096 8.8536
# HOBE 3.08 55.8776 9.2683
# HOBE 3.09 55.8609 9.2945
